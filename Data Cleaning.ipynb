# %%
# !pip install pybaseball
# Out:
# ...
#   Using cached pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached PyGithub-2.4.0-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl.metadata (8.7 kB)
# ...
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached pybaseball-2.2.7-py3-none-any.whl (426 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 10.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 11.0 MB/s eta 0:00:0000:0100:01
# Using cached PyGithub-2.4.0-py3-none-any.whl (362 kB)
# ...
# Using cached PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl (349 kB)
# ...
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 11.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from pybaseball import statcast
from pybaseball import playerid_lookup, statcast_pitcher

# %%
data = statcast(start_dt='2023-04-01', end_dt='2023-04-10')
data.head(1)
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/10 [00:00<?, ?it/s]/opt/anaconda3/envs/learn-env/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  10%|█         | 1/10 [00:01<00:09,  1.11s/it]/opt/anaconda3/envs/learn-env/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ...

# %%
data.shape
# Out:
# (40088, 94)

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

data.head(1)
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2392         CH 2023-10-01           89.0           -2.8           5.59
#
#           player_name  batter  pitcher     events    description  spin_dir  \
# 2392  Robertson, Nick  677008   687798  field_out  hit_into_play      <NA>
#
#       spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# 2392                  <NA>                    <NA>                     <NA>
#
#       zone                                                des game_type stand  \
# 2392     9  Heston Kjerstad grounds out, first baseman Bob...         R     L
#
#      p_throws home_team away_team type  hit_location      bb_type  balls  \
# 2392        R       BAL       BOS    X             3  ground_ball      2
#
#       strikes  game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  \
# 2392        2       2023  -1.53   0.33     0.33     2.01   <NA>   <NA>   <NA>
#
# ...

# %%
pd.set_option('display.max_rows', None)
print(data.dtypes)
# Out:
# pitch_type                                 object
# game_date                          datetime64[ns]
# release_speed                             Float64
# release_pos_x                             Float64
# release_pos_z                             Float64
# player_name                                object
# batter                                      Int64
# pitcher                                     Int64
# events                                     object
# description                                object
# spin_dir                                    Int64
# spin_rate_deprecated                        Int64
# break_angle_deprecated                      Int64
# break_length_deprecated                     Int64
# zone                                        Int64
# des                                        object
# game_type                                  object
# stand                                      object
# p_throws                                   object
# ...

# %%
start_date = '2023-04-01'
end_date = '2023-10-01'
data = statcast(start_dt=start_date, end_dt=end_date)
selected_columns = [
    'pitch_type', 'release_speed', 'player_name', 'stand', 'p_throws', 
    'balls', 'strikes', 'game_year', 'outs_when_up', 'inning', 
    'effective_speed', 'pitch_number', 'pitch_name', 'bat_score', 
    'fld_score', 'if_fielding_alignment', 'of_fielding_alignment'
]
filtered_data = data[selected_columns]
# Out:
# This is a large query, it may take a moment to complete
# /opt/anaconda3/envs/learn-env/lib/python3.12/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# ...

# %%
filtered_data.head(5)
# Out:
#      pitch_type  release_speed      player_name stand p_throws  balls  \
# 2392         CH           89.0  Robertson, Nick     L        R      2
# 2533         FF           96.9  Robertson, Nick     L        R      2
# 2631         CH           90.0  Robertson, Nick     L        R      1
# 2724         ST           82.2  Robertson, Nick     L        R      0
# 2791         CH           89.2  Robertson, Nick     L        R      0
#
#       strikes  game_year  outs_when_up  inning  effective_speed  pitch_number  \
# 2392        2       2023             2       9             90.7             6
# 2533        2       2023             2       9             98.4             5
# 2631        2       2023             2       9             91.5             4
# 2724        2       2023             2       9             82.4             3
# 2791        1       2023             2       9             90.5             2
#
#            pitch_name  bat_score  fld_score if_fielding_alignment  \
# ...

# %%
yamamoto_check = [name for name in filtered_data['player_name'].unique() if 'Flaherty, Jack' in name]
print(yamamoto_check)
# Out:
# ['Flaherty, Jack']
